# %% [markdown]
# # This is an example notebook for mass conservation test

# %% [markdown]
# After building ``RAPID``, the executable binary ``simulation`` is located in the bin folder.

# %%
import subprocess
import os

# ensure we run from project root if notebook is inside "notebooks"
cwd = os.getcwd()
if os.path.basename(cwd) == "notebooks":
    os.chdir("..")

yaml_files = [
    "notebooks/configs/mass_conservation_zero_gradient.yaml",
    "notebooks/configs/mass_conservation_parabolic.yaml",
    "notebooks/configs/mass_conservation_fixed_flux.yaml",
    "notebooks/configs/mass_conservation_absorbing.yaml",
    "notebooks/configs/mass_conservation_reflecting.yaml"
]

for yaml_path in yaml_files:
    print("\n==============================================")
    print(f"Running simulation for: {yaml_path}")
    print("==============================================\n")

    cmd = [
        "python3",
        "run_simulation.py",
        "--config",
        yaml_path
    ]

    process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

    for line in process.stdout:
        print(line.rstrip("\n"))

    process.wait()

    print(f"\nSimulation finished for: {yaml_path}\n")
# Out:
# ==============================================
# Running simulation for: notebooks/configs/mass_conservation_zero_gradient.yaml
# ==============================================
#
# [PY-WRAPPER] Terminal panels disabled (YAML setting).
#
# [PY-WRAPPER] --- Running: Main Simulation Program ---
# [PY-WRAPPER] The current command-line arguments are:
#  ./bin/simulation -v -no_panels -evol 1.0 -test mass_test -n 500 -ri 1.0 -ro 50.0 -disk_mass 0.01 -index_init 0.5 -alpha_init 0.01 -stellar_mass 1.0 -h_init 0.05 -flind_init 0.5 -inner_bc zero_gradient -outer_bc zero_gradient -o notebooks/mass_conservation_test_outputs/mass_test_zero_gradient -tmax 100000.0 -outfreq 20000.0
# [PY-WRAPPER] Setting OMP_NUM_THREADS=1 for this run.
# [PY-WRAPPER] Start running the binary (./bin/simulation) at 2026-09-15 19:05:08...
#
# ==========================================================================
# ||                                                                      ||
# ||                        RAPID SIMULATION CORE                         ||
# ||                            Version: 2.2.4                            ||
# ||                                                                      ||
# ||                  Lead Developer: [D. Tarczay-Nehez]                  ||
# ||                      Co-Developer: [A. Csaszar]                      ||
# ||                                                                      ||
# ==========================================================================
#
#                   Initializing simulation core...
#
#
# INFO [main]: Command-line options parsed successfully. Logging level set to 1.
# INFO [main]: Output subdirectories created.
#
# ==========================================================================
# ||                      INITIALIZATION PARAMETERS                       ||
# ==========================================================================
#   Stellar mass (Solar Mass):          1
#   Disk aspect ratio (H/R):            0.05
#   Disk flaring index:                 0.5
#   Alpha viscosity:                    0.01
#   Total disk mass (Solar Mass):       0.01
#   Inner disk edge (AU):               1
#   Outer disk edge (AU):               50
#   Profile Style:                      [Standard Pure Power-Law]
#   Surface density profile exponent:   0.5
#   Gas surface density at 1 AU:        6.77153e-06 M_Sun/AU^2
#   Number of gas grid points:          500
# ==========================================================================
# ==========================================================================
# ||                   >>> BENCHMARK MODE ACTIVATED <<<                   ||
# ||                          RUNNING BENCHMARK:                          ||
# ||                        Mass Conservation Test                        ||
# ==========================================================================
# ||                 >>> BENCHMARK OVERRIDES APPLIED <<<                  ||
# ==========================================================================
#                         Gas evolution: ENABLED
#                          Dust drift: DISABLED
#                         Dust growth: DISABLED
#                  Secondary dust population: DISABLED
#                       Photoevaporation: DISABLED
# ==========================================================================
#
# === [BENCHMARK] Starting Mass Conservation Test ===
# INFO [printBenchmarkStatus]: DISABLED REAL-TIME STATUS UPDATE PRINT
#
#
# ==========================================================================
# ||                    >>> BENCHMARKING COMPLETE <<<                     ||
# ||             All files are saved to the output directory:             ||
# ||   notebooks/mass_conservation_test_outputs/mass_test_zero_gradient   ||
# ==========================================================================
#
# [PY-WRAPPER] Main Simulation Program completed successfully.
# [PY-WRAPPER] All programs completed successfully.
#
# Simulation finished for: notebooks/configs/mass_conservation_zero_gradient.yaml
#
#
# ==============================================
# Running simulation for: notebooks/configs/mass_conservation_parabolic.yaml
# ==============================================
#
# [PY-WRAPPER] Terminal panels disabled (YAML setting).
#
# [PY-WRAPPER] --- Running: Main Simulation Program ---
# [PY-WRAPPER] The current command-line arguments are:
#  ./bin/simulation -v -no_panels -evol 1.0 -test mass_test -n 500 -ri 1.0 -ro 50.0 -disk_mass 0.01 -index_init 0.5 -alpha_init 0.01 -stellar_mass 1.0 -h_init 0.05 -flind_init 0.5 -inner_bc parabolic -outer_bc parabolic -o notebooks/mass_conservation_test_outputs/mass_test_parabolic -tmax 100000.0 -outfreq 20000.0
# [PY-WRAPPER] Setting OMP_NUM_THREADS=1 for this run.
# [PY-WRAPPER] Start running the binary (./bin/simulation) at 2026-09-15 19:05:29...
#
# ==========================================================================
# ||                                                                      ||
# ||                        RAPID SIMULATION CORE                         ||
# ||                            Version: 2.2.4                            ||
# ||                                                                      ||
# ||                  Lead Developer: [D. Tarczay-Nehez]                  ||
# ||                      Co-Developer: [A. Csaszar]                      ||
# ||                                                                      ||
# ==========================================================================
#
#                   Initializing simulation core...
#
#
# INFO [main]: Command-line options parsed successfully. Logging level set to 1.
# INFO [main]: Output subdirectories created.
#
# ==========================================================================
# ||                      INITIALIZATION PARAMETERS                       ||
# ==========================================================================
#   Stellar mass (Solar Mass):          1
#   Disk aspect ratio (H/R):            0.05
#   Disk flaring index:                 0.5
#   Alpha viscosity:                    0.01
#   Total disk mass (Solar Mass):       0.01
#   Inner disk edge (AU):               1
#   Outer disk edge (AU):               50
#   Profile Style:                      [Standard Pure Power-Law]
#   Surface density profile exponent:   0.5
#   Gas surface density at 1 AU:        6.77153e-06 M_Sun/AU^2
#   Number of gas grid points:          500
# ==========================================================================
# ==========================================================================
# ||                   >>> BENCHMARK MODE ACTIVATED <<<                   ||
# ||                          RUNNING BENCHMARK:                          ||
# ||                        Mass Conservation Test                        ||
# ==========================================================================
# ||                 >>> BENCHMARK OVERRIDES APPLIED <<<                  ||
# ==========================================================================
#                         Gas evolution: ENABLED
#                          Dust drift: DISABLED
#                         Dust growth: DISABLED
#                  Secondary dust population: DISABLED
#                       Photoevaporation: DISABLED
# ==========================================================================
#
# === [BENCHMARK] Starting Mass Conservation Test ===
# INFO [printBenchmarkStatus]: DISABLED REAL-TIME STATUS UPDATE PRINT
#
#
# ==========================================================================
# ||                    >>> BENCHMARKING COMPLETE <<<                     ||
# ||             All files are saved to the output directory:             ||
# ||     notebooks/mass_conservation_test_outputs/mass_test_parabolic     ||
# ==========================================================================
#
# [PY-WRAPPER] Main Simulation Program completed successfully.
# [PY-WRAPPER] All programs completed successfully.
#
# Simulation finished for: notebooks/configs/mass_conservation_parabolic.yaml
#
#
# ==============================================
# Running simulation for: notebooks/configs/mass_conservation_fixed_flux.yaml
# ==============================================
#
# [PY-WRAPPER] Terminal panels disabled (YAML setting).
#
# [PY-WRAPPER] --- Running: Main Simulation Program ---
# [PY-WRAPPER] The current command-line arguments are:
#  ./bin/simulation -v -no_panels -evol 1.0 -test mass_test -n 500 -ri 1.0 -ro 50.0 -disk_mass 0.01 -index_init 0.5 -alpha_init 0.01 -stellar_mass 1.0 -h_init 0.05 -flind_init 0.5 -inner_bc fixed_flux -outer_bc fixed_flux -o notebooks/mass_conservation_test_outputs/mass_test_fixed_flux -tmax 100000.0 -outfreq 20000.0
# [PY-WRAPPER] Setting OMP_NUM_THREADS=1 for this run.
# [PY-WRAPPER] Start running the binary (./bin/simulation) at 2026-09-15 19:05:51...
#
# ==========================================================================
# ||                                                                      ||
# ||                        RAPID SIMULATION CORE                         ||
# ||                            Version: 2.2.4                            ||
# ||                                                                      ||
# ||                  Lead Developer: [D. Tarczay-Nehez]                  ||
# ||                      Co-Developer: [A. Csaszar]                      ||
# ||                                                                      ||
# ==========================================================================
#
#                   Initializing simulation core...
#
#
# INFO [main]: Command-line options parsed successfully. Logging level set to 1.
# INFO [main]: Output subdirectories created.
#
# ==========================================================================
# ||                      INITIALIZATION PARAMETERS                       ||
# ==========================================================================
#   Stellar mass (Solar Mass):          1
#   Disk aspect ratio (H/R):            0.05
#   Disk flaring index:                 0.5
#   Alpha viscosity:                    0.01
#   Total disk mass (Solar Mass):       0.01
#   Inner disk edge (AU):               1
#   Outer disk edge (AU):               50
#   Profile Style:                      [Standard Pure Power-Law]
#   Surface density profile exponent:   0.5
#   Gas surface density at 1 AU:        6.77153e-06 M_Sun/AU^2
#   Number of gas grid points:          500
# ==========================================================================
# ==========================================================================
# ||                   >>> BENCHMARK MODE ACTIVATED <<<                   ||
# ||                          RUNNING BENCHMARK:                          ||
# ||                        Mass Conservation Test                        ||
# ==========================================================================
# ||                 >>> BENCHMARK OVERRIDES APPLIED <<<                  ||
# ==========================================================================
#                         Gas evolution: ENABLED
#                          Dust drift: DISABLED
#                         Dust growth: DISABLED
#                  Secondary dust population: DISABLED
#                       Photoevaporation: DISABLED
# ==========================================================================
#
# === [BENCHMARK] Starting Mass Conservation Test ===
# INFO [printBenchmarkStatus]: DISABLED REAL-TIME STATUS UPDATE PRINT
#
#
# ==========================================================================
# ||                    >>> BENCHMARKING COMPLETE <<<                     ||
# ||             All files are saved to the output directory:             ||
# ||    notebooks/mass_conservation_test_outputs/mass_test_fixed_flux     ||
# ==========================================================================
#
# [PY-WRAPPER] Main Simulation Program completed successfully.
# [PY-WRAPPER] All programs completed successfully.
#
# Simulation finished for: notebooks/configs/mass_conservation_fixed_flux.yaml
#
#
# ==============================================
# Running simulation for: notebooks/configs/mass_conservation_absorbing.yaml
# ==============================================
#
# [PY-WRAPPER] Terminal panels disabled (YAML setting).
#
# [PY-WRAPPER] --- Running: Main Simulation Program ---
# [PY-WRAPPER] The current command-line arguments are:
#  ./bin/simulation -v -no_panels -evol 1.0 -test mass_test -n 500 -ri 1.0 -ro 50.0 -disk_mass 0.01 -index_init 0.5 -alpha_init 0.01 -stellar_mass 1.0 -h_init 0.05 -flind_init 0.5 -inner_bc absorbing -outer_bc absorbing -o notebooks/mass_conservation_test_outputs/mass_test_absorbing -tmax 100000.0 -outfreq 20000.0
# [PY-WRAPPER] Setting OMP_NUM_THREADS=1 for this run.
# [PY-WRAPPER] Start running the binary (./bin/simulation) at 2026-09-15 19:06:11...
#
# ==========================================================================
# ||                                                                      ||
# ||                        RAPID SIMULATION CORE                         ||
# ||                            Version: 2.2.4                            ||
# ||                                                                      ||
# ||                  Lead Developer: [D. Tarczay-Nehez]                  ||
# ||                      Co-Developer: [A. Csaszar]                      ||
# ||                                                                      ||
# ==========================================================================
#
#                   Initializing simulation core...
#
#
# INFO [main]: Command-line options parsed successfully. Logging level set to 1.
# INFO [main]: Output subdirectories created.
#
# ==========================================================================
# ||                      INITIALIZATION PARAMETERS                       ||
# ==========================================================================
#   Stellar mass (Solar Mass):          1
#   Disk aspect ratio (H/R):            0.05
#   Disk flaring index:                 0.5
#   Alpha viscosity:                    0.01
#   Total disk mass (Solar Mass):       0.01
#   Inner disk edge (AU):               1
#   Outer disk edge (AU):               50
#   Profile Style:                      [Standard Pure Power-Law]
#   Surface density profile exponent:   0.5
#   Gas surface density at 1 AU:        6.77153e-06 M_Sun/AU^2
#   Number of gas grid points:          500
# ==========================================================================
# ==========================================================================
# ||                   >>> BENCHMARK MODE ACTIVATED <<<                   ||
# ||                          RUNNING BENCHMARK:                          ||
# ||                        Mass Conservation Test                        ||
# ==========================================================================
# ||                 >>> BENCHMARK OVERRIDES APPLIED <<<                  ||
# ==========================================================================
#                         Gas evolution: ENABLED
#                          Dust drift: DISABLED
#                         Dust growth: DISABLED
#                  Secondary dust population: DISABLED
#                       Photoevaporation: DISABLED
# ==========================================================================
#
# === [BENCHMARK] Starting Mass Conservation Test ===
# INFO [printBenchmarkStatus]: DISABLED REAL-TIME STATUS UPDATE PRINT
#
#
# ==========================================================================
# ||                    >>> BENCHMARKING COMPLETE <<<                     ||
# ||             All files are saved to the output directory:             ||
# ||     notebooks/mass_conservation_test_outputs/mass_test_absorbing     ||
# ==========================================================================
#
# [PY-WRAPPER] Main Simulation Program completed successfully.
# [PY-WRAPPER] All programs completed successfully.
#
# Simulation finished for: notebooks/configs/mass_conservation_absorbing.yaml
#
#
# ==============================================
# Running simulation for: notebooks/configs/mass_conservation_reflecting.yaml
# ==============================================
#
# [PY-WRAPPER] Terminal panels disabled (YAML setting).
#
# [PY-WRAPPER] --- Running: Main Simulation Program ---
# [PY-WRAPPER] The current command-line arguments are:
#  ./bin/simulation -v -no_panels -evol 1.0 -test mass_test -n 500 -ri 1.0 -ro 50.0 -disk_mass 0.01 -index_init 0.5 -alpha_init 0.01 -stellar_mass 1.0 -h_init 0.05 -flind_init 0.5 -inner_bc reflecting -outer_bc reflecting -o notebooks/mass_conservation_test_outputs/mass_test_reflecting -tmax 100000.0 -outfreq 20000.0
# [PY-WRAPPER] Setting OMP_NUM_THREADS=1 for this run.
# [PY-WRAPPER] Start running the binary (./bin/simulation) at 2026-09-15 19:06:30...
#
# ==========================================================================
# ||                                                                      ||
# ||                        RAPID SIMULATION CORE                         ||
# ||                            Version: 2.2.4                            ||
# ||                                                                      ||
# ||                  Lead Developer: [D. Tarczay-Nehez]                  ||
# ||                      Co-Developer: [A. Csaszar]                      ||
# ||                                                                      ||
# ==========================================================================
#
#                   Initializing simulation core...
#
#
# INFO [main]: Command-line options parsed successfully. Logging level set to 1.
# INFO [main]: Output subdirectories created.
#
# ==========================================================================
# ||                      INITIALIZATION PARAMETERS                       ||
# ==========================================================================
#   Stellar mass (Solar Mass):          1
#   Disk aspect ratio (H/R):            0.05
#   Disk flaring index:                 0.5
#   Alpha viscosity:                    0.01
#   Total disk mass (Solar Mass):       0.01
#   Inner disk edge (AU):               1
#   Outer disk edge (AU):               50
#   Profile Style:                      [Standard Pure Power-Law]
#   Surface density profile exponent:   0.5
#   Gas surface density at 1 AU:        6.77153e-06 M_Sun/AU^2
#   Number of gas grid points:          500
# ==========================================================================
# ==========================================================================
# ||                   >>> BENCHMARK MODE ACTIVATED <<<                   ||
# ||                          RUNNING BENCHMARK:                          ||
# ||                        Mass Conservation Test                        ||
# ==========================================================================
# ||                 >>> BENCHMARK OVERRIDES APPLIED <<<                  ||
# ==========================================================================
#                         Gas evolution: ENABLED
#                          Dust drift: DISABLED
#                         Dust growth: DISABLED
#                  Secondary dust population: DISABLED
#                       Photoevaporation: DISABLED
# ==========================================================================
#
# === [BENCHMARK] Starting Mass Conservation Test ===
# INFO [printBenchmarkStatus]: DISABLED REAL-TIME STATUS UPDATE PRINT
#
#
# ==========================================================================
# ||                    >>> BENCHMARKING COMPLETE <<<                     ||
# ||             All files are saved to the output directory:             ||
# ||    notebooks/mass_conservation_test_outputs/mass_test_reflecting     ||
# ==========================================================================
#
# [PY-WRAPPER] Main Simulation Program completed successfully.
# [PY-WRAPPER] All programs completed successfully.
#
# Simulation finished for: notebooks/configs/mass_conservation_reflecting.yaml

# %% [markdown]
# ## Disk mass evolution for the different boundary conditions

# %% [markdown]
# In all cases, the inner and outer boundaries are the same, no mixed BC conditions are investigated..

# %%
import numpy as np
import matplotlib.pyplot as plt

import os

# current working directory
cwd = os.getcwd()

# if we are NOT inside notebooks, try to find it
if os.path.basename(cwd) != "notebooks":
    # search for a notebooks directory in the current tree
    for root, dirs, files in os.walk(".", topdown=True):
        if "notebooks" in dirs:
            notebooks_path = os.path.join(root, "notebooks")
            os.chdir(notebooks_path)
            print(f"Changed directory to: {notebooks_path}")
            break
    else:
        print("No 'notebooks' directory found. Staying in current directory.")
else:
    print("Already inside notebooks.")


runs = {
    "Zero-Gradient": "mass_conservation_test_outputs/mass_test_zero_gradient/LOGS/mass_conservation_100k.dat",
    "Parabolic": "mass_conservation_test_outputs/mass_test_parabolic/LOGS/mass_conservation_100k.dat",
    "Fixed-Flux": "mass_conservation_test_outputs/mass_test_fixed_flux/LOGS/mass_conservation_100k.dat",
    "Absorbing": "mass_conservation_test_outputs/mass_test_absorbing/LOGS/mass_conservation_100k.dat",
    "Reflecting": "mass_conservation_test_outputs/mass_test_reflecting/LOGS/mass_conservation_100k.dat"
}

# Stílus beállítása
plt.style.use('seaborn-v0_8-whitegrid' if 'seaborn-v0_8-whitegrid' in plt.style.available else 'default')
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(7, 6), sharex=True)

colors = {
    'Zero-Gradient': '#1f77b4', 
    'Parabolic': '#2ca02c', 
    'Fixed-Flux': '#ff7f0e', 
    'Absorbing': '#d62728', 
    'Reflecting': '#9467bd'
}
linestyles = {
    'Zero-Gradient': '--', 
    'Parabolic': '-', 
    'Fixed-Flux': '-.', 
    'Absorbing': ':', 
    'Reflecting': '--'
}

# Alapadat betöltése a kiindulási tömeghez (M_0)
# A parabolic / első futás t=0 tömegét vesszük referenciának
ref_data = np.loadtxt("mass_conservation_test_outputs/output_mass_test_parabolic/LOGS/mass_conservation_100k.dat")
M0 = ref_data[0, 1]

for label, path in runs.items():
    try:
        data = np.loadtxt(path)
        time = data[:, 0]
        mass = data[:, 1]
        
        # Relatív eltérés a kezdeti tömegtől vagy az adott futás saját M0-jától
        # Itt a futás saját t=0 tömegéhez viszonyítjuk a relatív változást
        local_M0 = mass[0]
        rel_diff = np.abs(mass - local_M0) / local_M0
        
        # --- Felső panel: Tömeg evolúció ---
        ax1.plot(time, mass, label=label, color=colors.get(label, 'black'), 
                 linestyle=linestyles.get(label, '-'), lw=2)
        
        # --- Alsó panel: Relatív hiba / változás ---
        ax2.plot(time, rel_diff, label=label, color=colors.get(label, 'black'), 
                 linestyle=linestyles.get(label, '-'), lw=1.5)  # <--- Itt volt a hiányzó label=label!        
    except FileNotFoundError:
        print(f"Warning: File not found for {label} at {path}")

# Felső panel beállításai
ax1.set_ylabel(r'Total Disk Mass [$M_\odot$]', fontsize=15)
ax1.set_title('Comparison of Outer Boundary Conditions in Viscous Evolution', fontsize=14, fontweight='bold')
ax1.tick_params(axis='both', which='major', labelsize=13.5)

# Alsó panel beállításai
ax2.set_yscale('log')
ax2.set_xlabel('Physical Time [years]', fontsize=15)
ax2.set_ylabel(r'$|\Delta M / M_0|$', fontsize=15)
ax2.legend(loc='lower right', frameon=True, fontsize=13.5)
ax2.tick_params(axis='both', which='major', labelsize=13.5)

plt.tight_layout()

# Mentés nagy felbontású PNG-be
output_png = "mass_conservation_test_outputs/boundary_conditions_comparison.png"
plt.savefig(output_png, dpi=300)
print(f"Comparison plot successfully saved to: {output_png}")

plt.show()
# Out:
# Changed directory to: ./notebooks
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 53
#      43 linestyles = {
#      44     'Zero-Gradient': '--',
#      45     'Parabolic': '-',
#    (...)
#      48     'Reflecting': '--'
#      49 }
#      51 # Alapadat betöltése a kiindulási tömeghez (M_0)
#      52 # A parabolic / első futás t=0 tömegét vesszük referenciának
# ---> 53 ref_data = np.loadtxt("mass_conservation_test_outputs/output_mass_test_parabolic/LOGS/mass_conservation_100k.dat")
#      54 M0 = ref_data[0, 1]
#      56 for label, path in runs.items():
#
# File ~/Documents/Munka/dust_drift/.venv/lib/python3.9/site-packages/numpy/lib/_npyio_impl.py:1381, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1378 if isinstance(delimiter, bytes):
#    1379     delimiter = delimiter.decode('latin1')
# -> 1381 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382             converters=converters, skiplines=skiprows, usecols=usecols,
#    1383             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1384             max_rows=max_rows, quote=quotechar)
#    1386 return arr
#
# File ~/Documents/Munka/dust_drift/.venv/lib/python3.9/site-packages/numpy/lib/_npyio_impl.py:997, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     995     fname = os.fspath(fname)
#     996 if isinstance(fname, str):
# --> 997     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     998     if encoding is None:
#     999         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/Documents/Munka/dust_drift/.venv/lib/python3.9/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)
#     188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/Documents/Munka/dust_drift/.venv/lib/python3.9/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: mass_conservation_test_outputs/output_mass_test_parabolic/LOGS/mass_conservation_100k.dat not found.
